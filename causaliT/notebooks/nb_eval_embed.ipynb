# %%
from eval_fun import eval_embed
experiment = "../experiments/single/euler/single_Lie_CC_scm6_54916195"
eval_embed(experiment)
# Out:
# Experiment ID: single_Lie_CC_scm6_54916195
# Detected architecture: SingleCausalForecaster
# Found 5 k-fold directories: ['k_0', 'k_1', 'k_2', 'k_3', 'k_4']
#
# k_0: Found 11 checkpoints
#   Processing epoch 0: epoch0-initial.ckpt
#     ✓ Extracted 7 embeddings from epoch 0
#   Processing epoch 9: epoch=9-train_loss=0.00.ckpt
#     ✓ Extracted 7 embeddings from epoch 9
#   Processing epoch 19: epoch=19-train_loss=0.00.ckpt
#     ✓ Extracted 7 embeddings from epoch 19
#   Processing epoch 29: epoch=29-train_loss=0.00.ckpt
#     ✓ Extracted 7 embeddings from epoch 29
#   Processing epoch 39: epoch=39-train_loss=0.00.ckpt
#     ✓ Extracted 7 embeddings from epoch 39
#   Processing epoch 49: epoch=49-train_loss=0.00.ckpt
#     ✓ Extracted 7 embeddings from epoch 49
#   Processing epoch 59: epoch=59-train_loss=0.00.ckpt
#     ✓ Extracted 7 embeddings from epoch 59
#   Processing epoch 69: epoch=69-train_loss=0.00.ckpt
#     ✓ Extracted 7 embeddings from epoch 69
# ...
