# %%
from eval_fun import eval_train_metrics
experiment = "../experiments/single/local/single_Lie_CC_scm6_loc001"
df = eval_train_metrics(experiment)
# Out:
# Experiment ID: single_Lie_CC_scm6_loc001
# Found 5 k-fold directories: ['k_0', 'k_1', 'k_2', 'k_3', 'k_4']
#   ✓ Loaded k_0: 202 rows
#   ✓ Loaded k_1: 202 rows
#   ✓ Loaded k_2: 202 rows
#   ✓ Loaded k_3: 202 rows
#   ✓ Loaded k_4: 202 rows
#
# Total rows: 1010 from 5 folds
# c:\Users\ScipioneFrancesco\Documents\Projects\causaliT\notebooks\eval_fun.py:581: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   ax.set_yscale("log")
