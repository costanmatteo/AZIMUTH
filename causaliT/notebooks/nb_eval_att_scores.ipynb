# %%
from eval_fun import eval_attention_scores
experiment = "../experiments/single/local/single_Lie_CC_scm6_loc001"
eval_attention_scores(experiment)
# Out:
# Experiment ID: single_Lie_CC_scm6_loc001
# Loaded attention weights from ../experiments/single/local/single_Lie_CC_scm6_loc001\eval\eval_attention_scores\files\final_scores\attention_weights.npz
# Loaded phi tensors from ../experiments/single/local/single_Lie_CC_scm6_loc001\eval\eval_attention_scores\files\final_scores\phi_tensors.npz
# Loaded 5 predictions from ../experiments/single/local/single_Lie_CC_scm6_loc001\eval\eval_attention_scores\files\final_scores\predictions.pkl
#
# ✓ AttentionData loaded from ../experiments/single/local/single_Lie_CC_scm6_loc001\eval\eval_attention_scores\files\final_scores
#   Architecture: SingleCausalForecaster
#   Folds: 5
# Experiment already available. Data loaded!
# Global color scale: min=-0.0833, max=0.6691
# Row 0 (dec_self, phi=False) scale: min=-0.0323, max=0.1763
# Row 1 (dec_self, phi=True) scale: min=0.2778, max=0.5850
# Row 2 (dec_cross, phi=False) scale: min=-0.0833, max=0.3809
# Row 3 (dec_cross, phi=True) scale: min=0.4579, max=0.6691
# c:\Users\ScipioneFrancesco\Documents\Projects\causaliT\notebooks\plot_lib.py:270: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# Experiment already available. Data loaded!
# --- Computing DAG Recovery Metrics (Per-Fold) ---
#   Evaluating dec_cross...
#     k_0: Soft Hamming (phi) = 0.4930
#     k_1: Soft Hamming (phi) = 0.4784
#     k_2: Soft Hamming (phi) = 0.5000
#     k_3: Soft Hamming (phi) = 0.4747
#     k_4: Soft Hamming (phi) = 0.5000
#     Statistics: best=0.4747, mean=0.4892, worst=0.5000, std=0.0107
#   Evaluating dec_self...
#     k_0: Soft Hamming (phi) = 0.4232
#     k_1: Soft Hamming (phi) = 0.5092
#     k_2: Soft Hamming (phi) = 0.4763
#     k_3: Soft Hamming (phi) = 0.5111
#     k_4: Soft Hamming (phi) = 0.5243
#     Statistics: best=0.4232, mean=0.4888, worst=0.5243, std=0.0364
#   Saved: dag_metrics.json
# {'dataset': 'scm6',
#  'architecture': 'SingleCausalForecaster',
#  'soft_hamming_cross': {'best': 0.47466286023457843,
#   'mean': 0.48922268847624456,
#   'worst': 0.5000018080075582,
#   'std': 0.010723651371255133,
#   'per_fold': {'k_0': 0.49301572640736896,
#    'k_1': 0.4784364898999532,
#    'k_2': 0.5000018080075582,
#    'k_3': 0.47466286023457843,
#    'k_4': 0.4999965578317642}},
#  'soft_hamming_cross_source': 'phi',
#  'soft_hamming_self': {'best': 0.42319896817207336,
#   'mean': 0.4888328105211258,
#   'worst': 0.5243350937962532,
#   'std': 0.03643319262010214,
#   'per_fold': {'k_0': 0.42319896817207336,
#    'k_1': 0.5091771185398102,
#    'k_2': 0.476306788623333,
#    'k_3': 0.5111460834741592,
#    'k_4': 0.5243350937962532}},
#  'soft_hamming_self_source': 'phi'}
